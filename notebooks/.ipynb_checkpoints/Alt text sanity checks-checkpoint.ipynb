# %%
import re
import pickle

# %%
with open('icon_data.pkl', 'rb') as f:
    images, alt_texts = pickle.load(f)

del images

# %%
alt_texts
# Out:
# ['Blu Selection',
#  '岐阜県郡上の塗装会社\u3000河合塗装\u3000ローディング中です',
#  'Factorisation, HCF and LCM',
#  'دانلود کتاب صوتی انگلیسی همراه با متن',
#  'Top 5 Apple Mail Alternatives for iPhone',
#  '星卡里奶茶',
#  'No photo description available.',
#  'ä¼\x8aæ\xad\x8cä¹\x90å\x99¨',
#  '京阪ホールディングス',
#  '駐車場あります',
#  'STELLA McCARTNEY Eyewear E c',
#  'Instagram Logo',
#  'black (3)',
#  'Cover art',
#  'Highlights info row image',
#  'error',
#  'thunderbird master password',
#  'Get Satisfaction Home',
#  '😎',
#  '3-in-1 Cable - Beyond Geek',
#  'denim-dark blue (1)',
#  'hosting advice',
#  'inFakt.pl',
#  'ixigo.com',
#  'Free research poster template 14',
#  '@caisq',
#  'LinkedIn',
#  'netsh interface ip add dns name Ethernet',
#  '💪🏻',
#  'Mail',
#  'Benefits of Using a Church Texting Service',
#  'CBS Drama',
#  'Custom SMS short code',
#  'LifeSelector',
#  'red (10)',
#  '菓乐拼奶茶店加盟',
#  '😒',
#  'MSGM - Black eco-leather sneakers with logo',
#  '😱',
#  'Highlights info row image',
# ...

# %%
def get_n_digits(alt_text):
    digits = list('0123456789')
    return sum([int(c in digits)
                for c in alt_text])

# %%
def get_n_special_chars(alt_text):
    special_chars = list('!"#€%&/()=+?^.,;:-_@')
    return sum([int(c in special_chars)
                for c in alt_text])

# %%
def get_n_chinese_chars(alt_text):
    return sum([len(section)
                for section in re.findall(r'[\u4e00-\u9fff]+', alt_text)])

# %%
def is_valid(alt_text):
    if get_n_digits(alt_text) > 4:
        return False
    elif get_n_special_chars(alt_text) > 3:
        return False
    elif get_n_chinese_chars(alt_text) > 1:
        return False
    elif len(alt_text) > 75:
        return False
    elif len(alt_text) < 3:
        return False
    
    return True

# %%
valid_alt_texts = [alt_text
                   for alt_text in alt_texts
                   if is_valid(alt_text)]

# %%
len(valid_alt_texts)
# Out:
# 18728

# %%
valid_alt_texts
# Out:
# ['Blu Selection',
#  'Factorisation, HCF and LCM',
#  'دانلود کتاب صوتی انگلیسی همراه با متن',
#  'Top 5 Apple Mail Alternatives for iPhone',
#  'No photo description available.',
#  'ä¼\x8aæ\xad\x8cä¹\x90å\x99¨',
#  'STELLA McCARTNEY Eyewear E c',
#  'Instagram Logo',
#  'black (3)',
#  'Cover art',
#  'Highlights info row image',
#  'error',
#  'thunderbird master password',
#  'Get Satisfaction Home',
#  '3-in-1 Cable - Beyond Geek',
#  'denim-dark blue (1)',
#  'hosting advice',
#  'inFakt.pl',
#  'ixigo.com',
#  'Free research poster template 14',
#  '@caisq',
#  'LinkedIn',
#  'netsh interface ip add dns name Ethernet',
#  'Mail',
#  'Benefits of Using a Church Texting Service',
#  'CBS Drama',
#  'Custom SMS short code',
#  'LifeSelector',
#  'red (10)',
#  'MSGM - Black eco-leather sneakers with logo',
#  'Highlights info row image',
#  'Fontech',
#  'Sustainable Peace',
#  'Shkendija Tirane U19(Stat)',
#  'Services des Moniales de France',
#  'MikeRemmers',
#  'MagMount',
# ...
